# %% [markdown]
# ### corpdb_merge.py.ipynb
# - 지역별 수집 데이터 병합(마켓DB/법인DB/인허가DB/포털DB/기업DB)

# %%
# -*- coding: utf-8 -*-
"""
원본 엑셀들을 DB 종류(마켓DB/법인DB/인허가DB/포털DB)별로 모아
- DB별 통합 CSV (UTF-8, CP949) 생성
- 각 원본 파일별로도 merchant_code가 포함된 CSV 생성

주의:
- 이 단계에서는 '최소 가공'만 합니다. (정규화/슬롯 분류는 스테이징 단계에서)
- 결측치는 저장 직전에 공백("")으로 변환합니다.
- Parquet 캐시는 있으면 사용하고, pyarrow 미설치/에러 시 조용히 건너뜁니다.
"""

import re
import json
import pandas as pd
from pathlib import Path
from typing import Optional, List, Dict

# =====================================================
# 설정: 경로
#   - ROOT_DIR: 현재 작업 폴더(.)에서 지역/DB 폴더 구조를 탐색
#   - OUT_DIR : 결과 CSV를 떨어뜨릴 폴더
# =====================================================
ROOT_DIR = Path(".")
OUT_DIR  = Path("./_merged_csv")     # 최종 결과 폴더
OUT_DIR.mkdir(parents=True, exist_ok=True)

# Parquet 캐시(원본 XLSX → 1회만 변환해두고 재사용; pyarrow 없으면 자동 패스)
PARQUET_CACHE_DIR = OUT_DIR / "_xlsx_parquet_cache"
PARQUET_CACHE_DIR.mkdir(parents=True, exist_ok=True)

# =====================================================
# 설정: DB 식별/코드 접두사 (거래데이터에 쓸 DB만)
#   - 파일명에 아래 문자열이 들어가야 해당 DB로 분류
#   - merchant_code 접두사도 같이 정의
# =====================================================
DB_PREFIXES = ["마켓DB","법인DB","인허가DB","포털DB"]

ID_PREFIX = {
    "마켓DB":  "M",
    "법인DB":  "B",
    "인허가DB":"L",
    "포털DB":  "P"
}

# =====================================================
# 파일/유틸
# =====================================================
def match_db_prefix(file_name: str) -> Optional[str]:
    """
    파일명에 DB 키워드(마켓DB/법인DB/인허가DB/포털DB)가 포함되어 있으면
    해당 DB명을 반환, 아니면 None.
    """
    for prefix in DB_PREFIXES:
        if re.search(prefix, file_name, re.IGNORECASE):
            return prefix
    return None

def _cast_object_to_str(df: pd.DataFrame) -> pd.DataFrame:
    """
    object/혼합 타입 컬럼들을 문자열(string dtype)로 통일.
    - strip 적용
    - 빈 문자열("")은 None으로 바꿔둠 (저장 직전에 일괄 공백 처리 예정)
    """
    df2 = df.copy()
    obj_cols = df2.select_dtypes(include=["object"]).columns
    if len(obj_cols) > 0:
        df2[obj_cols] = df2[obj_cols].apply(lambda s: s.astype("string").str.strip())
        df2[obj_cols] = df2[obj_cols].replace({"": None})
    return df2

def read_excel_safe(path: Path) -> Optional[pd.DataFrame]:
    """
    엑셀을 읽되, 동일 파일은 1회만 읽고 Parquet 캐시로 재사용.
    - 캐시 읽기 실패(pyarrow 미설치/파일 파손 등) 시 Excel로 로드
    - Excel 로드 후에는 캐시를 새로 저장(실패해도 그냥 무시)
    """
    try:
        stat = path.stat()
        cache_name = f"{path.stem}__{int(stat.st_mtime)}.parquet"
        cache_path = PARQUET_CACHE_DIR / cache_name

        # 캐시가 있으면 우선 사용
        if cache_path.exists():
            try:
                df = pd.read_parquet(cache_path)
                return _cast_object_to_str(df)
            except Exception:
                # 캐시 사용 실패(의존성/파일문제) → 아래에서 Excel 로드
                pass

        # 엑셀 로드(첫 시트만, 전부 문자열로)
        df = pd.read_excel(path, sheet_name=0, engine="openpyxl", dtype=str)
        df = _cast_object_to_str(df)

        # 같은 stem의 오래된 캐시 제거 (파일 수정시간 달라지면 새 캐시 생성)
        for old in PARQUET_CACHE_DIR.glob(f"{path.stem}__*.parquet"):
            try:
                old.unlink()
            except Exception:
                pass

        # 신규 캐시 저장 (pyarrow 없으면 실패할 수 있으니 무시)
        try:
            df.to_parquet(cache_path, index=False)
        except Exception:
            pass

        return df

    except Exception as e:
        print(f"[WARN] {path} 읽기 실패: {e}")
        return None

def make_codes(prefix_letter: str, n: int, width: int = 7):
    """
    merchant_code 생성.
    예) prefix='M', n=3 → ['M0000001','M0000002','M0000003']
    """
    return [f"{prefix_letter}{i:0{width}d}" for i in range(1, n+1)]

def sanitize_cp949_value(x):
    """
    CP949로 저장 시 인코딩 불가 문자가 있으면 제거하도록 가공.
    None → "", 비문자/이모지 등은 무시하고 저장.
    """
    if x is None:
        return ""
    if not isinstance(x, str):
        x = str(x)
    return x.encode("cp949", errors="ignore").decode("cp949")

def sanitize_df_cp949(df: pd.DataFrame) -> pd.DataFrame:
    """
    DataFrame 전체를 CP949 안전 문자열로 변환한 사본 반환.
    """
    out = df.copy()
    for col in out.columns:
        out[col] = out[col].map(sanitize_cp949_value)
    return out

# =====================================================
# 저장 유틸 (CSV만)
#   - 통합본/파일별본 모두 여기로 저장
#   - 결측치는 저장 직전 전부 공백("")으로 변환
# =====================================================
def save_csv_formats(df: pd.DataFrame, path_base: Path, with_cp949: bool = True):
    """
    CSV(utf8/cp949) 저장. 결측은 공백으로 변환.
    - 결과 파일명은 path_base + ".utf8.csv", ".csv"
    """
    df_to_save = df.copy().fillna("")         # 결측 → 공백
    path_u8 = path_base.with_suffix(".utf8.csv")
    path_cp = path_base.with_suffix(".csv")

    # UTF-8(BOM) 저장: 엑셀 호환 위해 BOM 사용
    df_to_save.to_csv(path_u8, index=False, encoding="utf-8-sig")

    # CP949 저장: 윈도우/한글 엑셀 호환 필요 시
    if with_cp949:
        df_cp949 = sanitize_df_cp949(df_to_save)
        df_cp949.to_csv(path_cp, index=False, encoding="cp949")

    return path_u8.name, (path_cp.name if with_cp949 else None)

# =====================================================
# 병합 + 코드부여 + 저장 (DB별 통합 + 원본파일별)
#   - 지역 폴더별로 모인 동일 DB의 엑셀들을 수직 결합
#   - region/source_db/src_file 메타 컬럼 추가
#   - merchant_code 부여 후
#     1) DB별 통합 CSV 저장
#     2) 각 원본 파일별로 merchant_code 포함한 CSV 별도 저장
# =====================================================
def merge_clean_and_save(db_name: str, files: List[Path], out_dir: Path, make_code: bool = True):
    frames = []
    src_files: List[str] = []

    for fp in files:
        df = read_excel_safe(fp)
        if df is None:
            continue

        # region = 상위 폴더명(예: ROOT/서울/마켓DB_..xlsx → '서울')
        region = fp.parent.name

        # 메타 컬럼 삽입 (원본은 수정하지 않고 DataFrame에만 주입)
        df.insert(0, "region", region)
        df.insert(1, "source_db", db_name)
        df.insert(2, "src_file", str(fp))  # 원본 추적용(파일별 저장에 사용)

        frames.append(df)
        src_files.append(str(fp))

    if not frames:
        print(f"[INFO] {db_name}: 병합할 파일 없음")
        return

    # 수직 병합 (열 집합이 달라도 union 형태로 맞춰 들어감)
    merged = pd.concat(frames, axis=0, ignore_index=True, sort=False)

    # 전부 NaN인 완전 빈 행만 제거 (이름 결측 등은 유지)
    merged.dropna(how="all", inplace=True)

    # merchant_code 부여 (파일/폴더 정렬 후 호출하면 재현성↑)
    if make_code:
        prefix_letter = ID_PREFIX.get(db_name, db_name[:1].upper())
        codes = make_codes(prefix_letter, len(merged), width=7)
        if "merchant_code" in merged.columns:
            merged = merged.drop(columns=["merchant_code"])
        # src_file 뒤에 삽입하여 메타 컬럼들이 앞에 오도록 정리
        merged.insert(3, "merchant_code", codes)

    # ---- DB별 통합 저장 (CSV, 결측=공백) ----
    out_dir.mkdir(parents=True, exist_ok=True)
    base = out_dir / f"{db_name}_merged"
    # 통합본에서는 src_file은 불필요하므로 제거 후 저장
    u8, cp = save_csv_formats(merged.drop(columns=["src_file"], errors="ignore"), base, with_cp949=True)
    print(f"[OK] {db_name} 통합 저장 → {u8}, {cp} (행수 {len(merged):,})")

    # ---- 원본 파일별 저장 (merchant_code 포함) ----
    by_file_dir = out_dir / f"{db_name}_by_file"
    by_file_dir.mkdir(parents=True, exist_ok=True)

    # src_file 기준으로 그룹핑해서 파일별 결과 저장
    for src, sub in merged.groupby("src_file", dropna=False):
        src_path = Path(src)
        stem = src_path.stem
        sub_to_save = sub.drop(columns=["src_file"], errors="ignore")
        save_csv_formats(sub_to_save, by_file_dir / f"{stem}_with_code", with_cp949=True)
        print(f"  └─ 원본[{stem}] 저장 완료 (행수 {len(sub_to_save):,})")

# =====================================================
# 메인
#   - ROOT_DIR 하위의 지역 폴더들을 순회
#   - 각 폴더 안의 *.xlsx 중 파일명에 DB 키워드가 포함된 것만 수집
#   - DB별로 정렬(폴더명, 파일명) 후 merge_clean_and_save 실행
# =====================================================
def main():
    files_by_db: Dict[str, List[Path]] = {p: [] for p in DB_PREFIXES}

    # 지역 폴더(예: ./서울, ./부산 ...)를 순회
    for region_dir in ROOT_DIR.iterdir():
        if region_dir.is_dir():
            # 각 지역 폴더의 엑셀 파일 탐색
            for path in region_dir.glob("*.xlsx"):
                dbp = match_db_prefix(path.name)
                if dbp:
                    files_by_db[dbp].append(path)

    # DB별로 파일 리스트를 정렬(폴더명, 파일명) → merchant_code 안정성↑
    for db_name, files in files_by_db.items():
        files = sorted(files, key=lambda p: (p.parent.name, p.name))
        merge_clean_and_save(
            db_name,
            files,
            OUT_DIR,
            make_code=True,   # merchant_code 부여 (False로 두면 미부여)
        )

    print("\n✅ 전체 완료: DB별 통합 + 원본파일별(merchant_code 포함) CSV 생성")

if __name__ == "__main__":
    main()
# Out:
# [OK] 마켓DB 통합 저장 → 마켓DB_merged.utf8.csv, 마켓DB_merged.csv (행수 591,803)
#   └─ 원본[마켓DB_1번_1757561915] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757561918] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757561922] 저장 완료 (행수 2,224)
#   └─ 원본[마켓DB_10번_1757491387] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_11번_1757491404] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_12번_1757491408] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_13번_1757491412] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_14번_1757491416] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_15번_1757491420] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_16번_1757491425] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_17번_1757491429] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_18번_1757491434] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_19번_1757491438] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_1번_1757491353] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_20번_1757491442] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_21번_1757491466] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_22번_1757491472] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_23번_1757491476] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_24번_1757491482] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_25번_1757491487] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_26번_1757491491] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_27번_1757491496] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_28번_1757491502] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_29번_1757491506] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757491356] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_30번_1757491510] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_31번_1757491522] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_32번_1757491525] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_33번_1757491530] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_34번_1757491534] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_35번_1757491537] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_36번_1757491542] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_37번_1757491545] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_38번_1757491550] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_39번_1757491554] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757491359] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_40번_1757491558] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_41번_1757491580] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_42번_1757491585] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_43번_1757491589] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_44번_1757491594] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_45번_1757491598] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_46번_1757491602] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_47번_1757491606] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_48번_1757491610] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_49번_1757491615] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_4번_1757491362] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_50번_1757491619] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_51번_1757491638] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_52번_1757491642] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_53번_1757491646] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_54번_1757491650] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_55번_1757491654] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_56번_1757491658] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_57번_1757491662] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_58번_1757491666] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_59번_1757491671] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_5번_1757491366] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_60번_1757491675] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_61번_1757491696] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_62번_1757491700] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_63번_1757491704] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_64번_1757491707] 저장 완료 (행수 2,475)
#   └─ 원본[마켓DB_6번_1757491369] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_7번_1757491373] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_8번_1757491378] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_9번_1757491382] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_1번_1757650637] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757650640] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757650643] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_4번_1757650647] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_5번_1757650651] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_6번_1757650655] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_7번_1757650659] 저장 완료 (행수 2,448)
#   └─ 원본[마켓DB_1번_1757648279] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757648286] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757648292] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_4번_1757648300] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_5번_1757648307] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_6번_1757648315] 저장 완료 (행수 1,993)
#   └─ 원본[마켓DB_1번_1757654986] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757654990] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757654994] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_4번_1757654998] 저장 완료 (행수 2,364)
#   └─ 원본[마켓DB_1번_1757636599] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757636604] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757636610] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_4번_1757636615] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_5번_1757636624] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_6번_1757636630] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_7번_1757636637] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_8번_1757636644] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_9번_1757636649] 저장 완료 (행수 1,104)
#   └─ 원본[마켓DB_1번_1757566577] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757566581] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757566589] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_4번_1757566594] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_5번_1757566599] 저장 완료 (행수 2,647)
#   └─ 원본[마켓DB_10번_1757984050] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_11번_1757984072] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_12번_1757984077] 저장 완료 (행수 1,604)
#   └─ 원본[마켓DB_1번_1757984017] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757984020] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757984023] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_4번_1757984026] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_5번_1757984030] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_6번_1757984034] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_7번_1757984038] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_8번_1757984042] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_9번_1757984046] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_10번_1757054246] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_11번_1757054264] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_12번_1757054268] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_13번_1757054272] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_14번_1757054277] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_15번_1757054282] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_16번_1757054286] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_17번_1757054290] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_18번_1757054294] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_19번_1757054298] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_1번_1757054210] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_20번_1757054302] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_21번_1757054318] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_22번_1757054322] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_23번_1757054326] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_24번_1757054330] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_25번_1757054334] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_26번_1757054338] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_27번_1757054342] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_28번_1757054346] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_29번_1757054350] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757054214] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_30번_1757054354] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_31번_1757054378] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_32번_1757054382] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_33번_1757054386] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_34번_1757054390] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_35번_1757054394] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_36번_1757054398] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_37번_1757054402] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_38번_1757054406] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_39번_1757054410] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757054218] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_40번_1757054414] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_41번_1757054431] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_42번_1757054435] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_43번_1757054439] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_44번_1757054443] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_45번_1757054447] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_46번_1757054451] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_47번_1757054455] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_48번_1757054459] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_49번_1757054463] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_4번_1757054222] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_50번_1757054467] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_51번_1757054477] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_52번_1757054482] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_53번_1757054486] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_54번_1757054490] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_55번_1757054494] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_56번_1757054498] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_57번_1757054502] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_58번_1757054505] 저장 완료 (행수 2,291)
#   └─ 원본[마켓DB_5번_1757054226] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_6번_1757054230] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_7번_1757054234] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_8번_1757054238] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_9번_1757054242] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_1번_1757981094] 저장 완료 (행수 2,672)
#   └─ 원본[마켓DB_1번_1757580295] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757580301] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757580305] 저장 완료 (행수 414)
#   └─ 원본[마켓DB_10번_1757509079] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_11번_1757509100] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_12번_1757509106] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_13번_1757509113] 저장 완료 (행수 2,905)
#   └─ 원본[마켓DB_1번_1757509036] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757509041] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757509045] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_4번_1757509049] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_5번_1757509053] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_6번_1757509057] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_7번_1757509062] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_8번_1757509067] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_9번_1757509073] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_1번_1757653358] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757653362] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757653366] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_4번_1757653370] 저장 완료 (행수 506)
#   └─ 원본[마켓DB_1번_1757656969] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757656973] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757656977] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_4번_1757656981] 저장 완료 (행수 544)
#   └─ 원본[마켓DB_1번_1757658264] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757658272] 저장 완료 (행수 1,545)
#   └─ 원본[마켓DB_1번_1757565467] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757565472] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757565479] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_4번_1757565485] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_5번_1757565491] 저장 완료 (행수 1,285)
#   └─ 원본[마켓DB_1번_1757575409] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_2번_1757575415] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_3번_1757575425] 저장 완료 (행수 3,000)
#   └─ 원본[마켓DB_4번_1757575496] 저장 완료 (행수 1,782)
# [OK] 법인DB 통합 저장 → 법인DB_merged.utf8.csv, 법인DB_merged.csv (행수 730,602)
#   └─ 원본[법인DB_1번_1757562005] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757562007] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757562010] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757562012] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_5번_1757562015] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757562017] 저장 완료 (행수 1,023)
#   └─ 원본[법인DB_10번_1757492389] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_11번_1757492400] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_12번_1757492404] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_13번_1757492408] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_14번_1757492412] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_15번_1757492415] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_16번_1757492418] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_17번_1757492422] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_18번_1757492425] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_19번_1757492429] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_1번_1757492359] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_20번_1757492432] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_21번_1757492451] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_22번_1757492455] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_23번_1757492459] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_24번_1757492463] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_25번_1757492467] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_26번_1757492471] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_27번_1757492475] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_28번_1757492479] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_29번_1757492483] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757492362] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_30번_1757492487] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_31번_1757492501] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_32번_1757492505] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_33번_1757492509] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_34번_1757492513] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_35번_1757492517] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_36번_1757492521] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_37번_1757492525] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_38번_1757492529] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_39번_1757492532] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757492365] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_40번_1757492536] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_41번_1757492553] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_42번_1757492556] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_43번_1757492560] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_44번_1757492564] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_45번_1757492567] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_46번_1757492571] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_47번_1757492575] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_48번_1757492578] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_49번_1757492582] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757492368] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_50번_1757492585] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_51번_1757492604] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_52번_1757492608] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_53번_1757492612] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_54번_1757492616] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_55번_1757492620] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_56번_1757492624] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_57번_1757492627] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_58번_1757492631] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_59번_1757492634] 저장 완료 (행수 2,566)
#   └─ 원본[법인DB_5번_1757492371] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757492374] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_7번_1757492378] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_8번_1757492381] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_9번_1757492385] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_10번_1757650892] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_11번_1757650910] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_12번_1757650912] 저장 완료 (행수 2,181)
#   └─ 원본[법인DB_1번_1757650868] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757650871] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757650874] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757650876] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_5번_1757650879] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757650881] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_7번_1757650884] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_8번_1757650887] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_9번_1757650889] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_10번_1757648531] 저장 완료 (행수 1,160)
#   └─ 원본[법인DB_1번_1757648506] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757648508] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757648511] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757648513] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_5번_1757648516] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757648519] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_7번_1757648522] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_8번_1757648525] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_9번_1757648528] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_1번_1757655110] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757655112] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757655115] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757655118] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_5번_1757655120] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757655122] 저장 완료 (행수 215)
#   └─ 원본[법인DB_1번_1757640020] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757640022] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757640026] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757640029] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_5번_1757640032] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757640035] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_7번_1757640038] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_8번_1757640040] 저장 완료 (행수 414)
#   └─ 원본[법인DB_1번_1757571650] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757571652] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757571655] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757571657] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_5번_1757571660] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757571662] 저장 완료 (행수 458)
#   └─ 원본[법인DB_10번_1757984412] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_11번_1757984431] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_12번_1757984434] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_13번_1757984437] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_14번_1757984440] 저장 완료 (행수 1,216)
#   └─ 원본[법인DB_1번_1757984387] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757984389] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757984392] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757984395] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_5번_1757984397] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757984400] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_7번_1757984403] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_8번_1757984406] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_9번_1757984409] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_10번_1757056485] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_11번_1757056508] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_12번_1757056513] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_13번_1757056518] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_14번_1757056522] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_15번_1757056526] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_16번_1757056530] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_17번_1757056534] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_18번_1757056538] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_19번_1757056542] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_1번_1757056449] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_20번_1757056546] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_21번_1757056561] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_22번_1757056565] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_23번_1757056570] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_24번_1757056574] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_25번_1757056578] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_26번_1757056583] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_27번_1757056587] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_28번_1757056591] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_29번_1757056595] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757056453] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_30번_1757056600] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_31번_1757056624] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_32번_1757056628] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_33번_1757056632] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_34번_1757056637] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_35번_1757056641] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_36번_1757056645] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_37번_1757056649] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_38번_1757056653] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_39번_1757056657] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757056456] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_40번_1757056662] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_41번_1757056687] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_42번_1757056691] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_43번_1757056695] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_44번_1757056700] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_45번_1757056704] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_46번_1757056708] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_47번_1757056712] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_48번_1757056717] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_49번_1757056720] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757056459] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_50번_1757056725] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_51번_1757056748] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_52번_1757056752] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_53번_1757056756] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_54번_1757056760] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_55번_1757056764] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_56번_1757056768] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_57번_1757056773] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_58번_1757056777] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_59번_1757056782] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_5번_1757056465] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_60번_1757056786] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_61번_1757056806] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_62번_1757056811] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_63번_1757056816] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_64번_1757056821] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_65번_1757056825] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_66번_1757056829] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_67번_1757056833] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_68번_1757056837] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_69번_1757056841] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757056469] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_70번_1757056846] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_71번_1757056867] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_72번_1757056871] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_73번_1757056875] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_74번_1757056879] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_75번_1757056883] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_76번_1757056887] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_77번_1757056891] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_78번_1757056895] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_79번_1757056899] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_7번_1757056473] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_80번_1757056903] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_81번_1757056925] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_82번_1757056929] 저장 완료 (행수 1,354)
#   └─ 원본[법인DB_8번_1757056477] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_9번_1757056481] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_1번_1757981198] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757981200] 저장 완료 (행수 84)
#   └─ 원본[법인DB_1번_1757580353] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757580355] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757580358] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757580360] 저장 완료 (행수 2,983)
#   └─ 원본[법인DB_10번_1757548570] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_11번_1757548594] 저장 완료 (행수 1,232)
#   └─ 원본[법인DB_1번_1757548546] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757548548] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757548551] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757548553] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_5번_1757548556] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757548559] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_7번_1757548561] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_8번_1757548564] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_9번_1757548567] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_1번_1757653812] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757653815] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757653817] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757653820] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_5번_1757653822] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757653825] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_7번_1757653827] 저장 완료 (행수 342)
#   └─ 원본[법인DB_1번_1757657031] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757657034] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757657036] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757657039] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_5번_1757657042] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757657044] 저장 완료 (행수 902)
#   └─ 원본[법인DB_1번_1757658486] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757658488] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757658491] 저장 완료 (행수 1,991)
#   └─ 원본[법인DB_1번_1757565684] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757565687] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757565689] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757565692] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_5번_1757565694] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757565697] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_7번_1757565700] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_8번_1757565702] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_9번_1757565705] 저장 완료 (행수 1,790)
#   └─ 원본[법인DB_1번_1757575548] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_2번_1757575551] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_3번_1757575553] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_4번_1757575556] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_5번_1757575559] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_6번_1757575561] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_7번_1757575564] 저장 완료 (행수 3,000)
#   └─ 원본[법인DB_8번_1757575566] 저장 완료 (행수 2,691)
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\2523204589.py:199: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged = pd.concat(frames, axis=0, ignore_index=True, sort=False)
# [OK] 인허가DB 통합 저장 → 인허가DB_merged.utf8.csv, 인허가DB_merged.csv (행수 7,826,880)
#   └─ 원본[인허가DB_100번_1757561774] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_101번_1757561794] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_102번_1757561799] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_103번_1757561804] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_104번_1757561809] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_105번_1757561814] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_106번_1757561819] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_107번_1757561824] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_108번_1757561829] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_109번_1757561834] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_10번_1757561204] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_110번_1757561838] 저장 완료 (행수 79)
#   └─ 원본[인허가DB_11번_1757561227] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_12번_1757561231] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_13번_1757561238] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_14번_1757561242] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_15번_1757561247] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_16번_1757561251] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_17번_1757561255] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_18번_1757561259] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_19번_1757561264] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_1번_1757561161] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_20번_1757561268] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_21번_1757561290] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_22번_1757561294] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_23번_1757561298] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_24번_1757561303] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_25번_1757561308] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_26번_1757561313] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_27번_1757561318] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_28번_1757561323] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_29번_1757561327] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_2번_1757561170] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_30번_1757561332] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_31번_1757561351] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_32번_1757561357] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_33번_1757561361] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_34번_1757561366] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_35번_1757561371] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_36번_1757561377] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_37번_1757561381] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_38번_1757561386] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_39번_1757561392] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_3번_1757561175] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_40번_1757561396] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_41번_1757561415] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_42번_1757561420] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_43번_1757561426] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_44번_1757561430] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_45번_1757561435] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_46번_1757561440] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_47번_1757561445] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_48번_1757561450] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_49번_1757561455] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_4번_1757561179] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_50번_1757561461] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_51번_1757561482] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_52번_1757561487] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_53번_1757561492] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_54번_1757561497] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_55번_1757561502] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_56번_1757561507] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_57번_1757561512] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_58번_1757561517] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_59번_1757561522] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_5번_1757561183] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_60번_1757561528] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_61번_1757561546] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_62번_1757561551] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_63번_1757561556] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_64번_1757561561] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_65번_1757561566] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_66번_1757561572] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_67번_1757561577] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_68번_1757561582] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_69번_1757561587] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_6번_1757561187] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_70번_1757561593] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_71번_1757561607] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_72번_1757561612] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_73번_1757561617] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_74번_1757561622] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_75번_1757561627] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_76번_1757561632] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_77번_1757561637] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_78번_1757561642] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_79번_1757561647] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_7번_1757561191] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_80번_1757561652] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_81번_1757561669] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_82번_1757561674] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_83번_1757561679] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_84번_1757561684] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_85번_1757561689] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_86번_1757561694] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_87번_1757561699] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_88번_1757561704] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_89번_1757561709] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_8번_1757561196] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_90번_1757561714] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_91번_1757561728] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_92번_1757561733] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_93번_1757561738] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_94번_1757561744] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_95번_1757561749] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_96번_1757561753] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_97번_1757561759] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_98번_1757561764] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_99번_1757561769] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_9번_1757561200] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_100번_1757479456] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_101번_1757479481] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_102번_1757479499] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_103번_1757479517] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_104번_1757479535] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_105번_1757479553] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_106번_1757479571] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_107번_1757479590] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_108번_1757479608] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_109번_1757479626] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_10번_1757478288] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_110번_1757479645] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_111번_1757479686] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_112번_1757479704] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_113번_1757479724] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_114번_1757479743] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_115번_1757479762] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_116번_1757479781] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_117번_1757479801] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_118번_1757479821] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_119번_1757479841] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_11번_1757478308] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_120번_1757479862] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_121번_1757479889] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_122번_1757479909] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_123번_1757479930] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_124번_1757479951] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_125번_1757479972] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_126번_1757479993] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_127번_1757480015] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_128번_1757480076] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_129번_1757480092] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_12번_1757478314] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_130번_1757480106] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_131번_1757480138] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_132번_1757480153] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_133번_1757480167] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_134번_1757480181] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_135번_1757480197] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_136번_1757480211] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_137번_1757480226] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_138번_1757480241] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_139번_1757480255] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_13번_1757478319] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_140번_1757480270] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_141번_1757480304] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_142번_1757480318] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_143번_1757480333] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_144번_1757480347] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_145번_1757480362] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_146번_1757480376] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_147번_1757480391] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_148번_1757480404] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_149번_1757480419] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_14번_1757478324] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_150번_1757480436] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_151번_1757480458] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_152번_1757480472] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_153번_1757480486] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_154번_1757480504] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_155번_1757480518] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_156번_1757480534] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_157번_1757480548] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_158번_1757480562] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_159번_1757480576] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_15번_1757478331] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_160번_1757480590] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_161번_1757480611] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_162번_1757480625] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_163번_1757480642] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_164번_1757480655] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_165번_1757480669] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_166번_1757480684] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_167번_1757480699] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_168번_1757480713] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_169번_1757480727] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_16번_1757478336] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_170번_1757480741] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_171번_1757480776] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_172번_1757480790] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_173번_1757480804] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_174번_1757480818] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_175번_1757480832] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_176번_1757480846] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_177번_1757480861] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_178번_1757480875] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_179번_1757480890] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_17번_1757478342] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_180번_1757480904] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_181번_1757480930] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_182번_1757480945] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_183번_1757480960] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_184번_1757480974] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_185번_1757480989] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_186번_1757481004] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_187번_1757481020] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_188번_1757481035] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_189번_1757481049] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_18번_1757478348] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_190번_1757481064] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_191번_1757481086] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_192번_1757481101] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_193번_1757481116] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_194번_1757481131] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_195번_1757481146] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_196번_1757481160] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_197번_1757481175] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_198번_1757481189] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_199번_1757481204] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_19번_1757478355] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_1번_1757478256] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_200번_1757481221] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_201번_1757481245] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_202번_1757481259] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_203번_1757481274] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_204번_1757481288] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_205번_1757481303] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_206번_1757481319] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_207번_1757481333] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_208번_1757481348] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_209번_1757481363] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_20번_1757478362] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_210번_1757481378] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_211번_1757481403] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_212번_1757481418] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_213번_1757481433] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_214번_1757481448] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_215번_1757481463] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_216번_1757481483] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_217번_1757481501] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_218번_1757481519] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_219번_1757481538] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_21번_1757478379] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_220번_1757481556] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_221번_1757481585] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_222번_1757481604] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_223번_1757481622] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_224번_1757481641] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_225번_1757481659] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_226번_1757481677] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_227번_1757481696] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_228번_1757481714] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_229번_1757481733] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_22번_1757478386] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_230번_1757481752] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_231번_1757481787] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_232번_1757481806] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_233번_1757481824] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_234번_1757481843] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_235번_1757481860] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_236번_1757481879] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_237번_1757481897] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_238번_1757481914] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_239번_1757481932] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_23번_1757478394] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_240번_1757481947] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_241번_1757481981] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_242번_1757481996] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_243번_1757482011] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_244번_1757482027] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_245번_1757482041] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_246번_1757482056] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_247번_1757482071] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_248번_1757482086] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_249번_1757482101] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_24번_1757478402] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_250번_1757482116] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_251번_1757482145] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_252번_1757482160] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_253번_1757482175] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_254번_1757482193] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_255번_1757482208] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_256번_1757482223] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_257번_1757482238] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_258번_1757482253] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_259번_1757482268] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_25번_1757478410] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_260번_1757482283] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_261번_1757482313] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_262번_1757482328] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_263번_1757482343] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_264번_1757482358] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_265번_1757482373] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_266번_1757482389] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_267번_1757482407] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_268번_1757482425] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_269번_1757482442] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_26번_1757478417] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_270번_1757482457] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_271번_1757482482] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_272번_1757482501] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_273번_1757482519] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_274번_1757482538] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_275번_1757482556] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_276번_1757482575] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_277번_1757482593] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_278번_1757482611] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_279번_1757482630] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_27번_1757478424] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_280번_1757482649] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_281번_1757482680] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_282번_1757482699] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_283번_1757482717] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_284번_1757482736] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_285번_1757482754] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_286번_1757482772] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_287번_1757482791] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_288번_1757482810] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_289번_1757482828] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_28번_1757478432] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_290번_1757482847] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_291번_1757482874] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_292번_1757482893] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_293번_1757482912] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_294번_1757482930] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_295번_1757482949] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_296번_1757482964] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_297번_1757482979] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_298번_1757482994] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_299번_1757483009] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_29번_1757478444] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_2번_1757478258] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_300번_1757483024] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_301번_1757483060] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_302번_1757483075] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_303번_1757483090] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_304번_1757483105] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_305번_1757483120] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_306번_1757483136] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_307번_1757483151] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_308번_1757483166] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_309번_1757483181] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_30번_1757478452] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_310번_1757483196] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_311번_1757483220] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_312번_1757483235] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_313번_1757483250] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_314번_1757483265] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_315번_1757483281] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_317번_1757483313] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_318번_1757483327] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_319번_1757483349] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_31번_1757478469] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_320번_1757483368] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_321번_1757483399] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_322번_1757483418] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_323번_1757483438] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_324번_1757483454] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_325번_1757483471] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_326번_1757483489] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_327번_1757483505] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_328번_1757483522] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_329번_1757483541] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_32번_1757478477] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_330번_1757483561] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_331번_1757483597] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_332번_1757483616] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_333번_1757483636] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_334번_1757483656] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_335번_1757483672] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_336번_1757483688] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_337번_1757483704] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_338번_1757483721] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_339번_1757483737] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_33번_1757478487] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_340번_1757483755] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_341번_1757483789] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_342번_1757483810] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_343번_1757483830] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_344번_1757483845] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_345번_1757483863] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_346번_1757483883] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_347번_1757483901] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_348번_1757483916] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_349번_1757483935] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_34번_1757478497] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_350번_1757483956] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_351번_1757483986] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_352번_1757484005] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_353번_1757484024] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_354번_1757484044] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_355번_1757484063] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_356번_1757484083] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_357번_1757484102] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_358번_1757484122] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_359번_1757484141] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_35번_1757478505] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_360번_1757484162] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_361번_1757484203] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_362번_1757484224] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_363번_1757484245] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_364번_1757484263] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_365번_1757484283] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_366번_1757484304] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_367번_1757484325] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_368번_1757484347] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_369번_1757484364] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_36번_1757478514] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_370번_1757484380] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_371번_1757484413] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_372번_1757484429] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_373번_1757484445] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_374번_1757484461] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_375번_1757484477] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_376번_1757484493] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_377번_1757484509] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_378번_1757484525] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_379번_1757484541] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_37번_1757478524] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_380번_1757484557] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_381번_1757484590] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_382번_1757484606] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_383번_1757484623] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_384번_1757484645] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_385번_1757484665] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_386번_1757484687] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_387번_1757484706] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_388번_1757484725] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_389번_1757484744] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_38번_1757478534] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_390번_1757484765] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_391번_1757484797] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_392번_1757484818] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_393번_1757484838] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_394번_1757484857] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_395번_1757484877] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_396번_1757484896] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_397번_1757484917] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_398번_1757484938] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_399번_1757484959] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_39번_1757478542] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_3번_1757478261] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_400번_1757484977] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_401번_1757485012] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_402번_1757485029] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_403번_1757485045] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_404번_1757485061] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_405번_1757485080] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_406번_1757485095] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_407번_1757485111] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_408번_1757485131] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_409번_1757485151] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_40번_1757478553] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_410번_1757485173] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_411번_1757485212] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_412번_1757485234] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_413번_1757485255] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_414번_1757485276] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_415번_1757485323] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_416번_1757485344] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_417번_1757485366] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_418번_1757485387] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_419번_1757485408] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_41번_1757478579] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_420번_1757485429] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_421번_1757485460] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_422번_1757485481] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_423번_1757485502] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_424번_1757485523] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_425번_1757485544] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_426번_1757485565] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_427번_1757485586] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_428번_1757485607] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_429번_1757485628] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_42번_1757478588] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_430번_1757485649] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_431번_1757485690] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_432번_1757485710] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_433번_1757485732] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_434번_1757485753] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_435번_1757485774] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_436번_1757485793] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_437번_1757485810] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_438번_1757485827] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_439번_1757485844] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_43번_1757478599] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_440번_1757485861] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_441번_1757485895] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_442번_1757485913] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_443번_1757485930] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_444번_1757485947] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_445번_1757485964] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_446번_1757485981] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_447번_1757485998] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_448번_1757486015] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_449번_1757486032] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_44번_1757478608] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_450번_1757486050] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_451번_1757486074] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_452번_1757486091] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_453번_1757486108] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_454번_1757486125] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_455번_1757486142] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_456번_1757486163] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_457번_1757486185] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_458번_1757486206] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_459번_1757486226] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_45번_1757478618] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_460번_1757486245] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_461번_1757486283] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_462번_1757486300] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_463번_1757486317] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_464번_1757486334] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_465번_1757486351] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_466번_1757486368] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_467번_1757486390] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_468번_1757486411] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_469번_1757486432] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_46번_1757478628] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_470번_1757486453] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_471번_1757486486] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_472번_1757486507] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_473번_1757486525] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_474번_1757486542] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_475번_1757486562] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_476번_1757486585] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_477번_1757486607] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_478번_1757486629] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_479번_1757486651] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_47번_1757478639] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_480번_1757486673] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_481번_1757486702] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_482번_1757486723] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_483번_1757486741] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_484번_1757486758] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_485번_1757486775] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_486번_1757486792] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_487번_1757486815] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_488번_1757486837] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_489번_1757486859] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_48번_1757478649] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_490번_1757486881] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_491번_1757486923] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_492번_1757486946] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_493번_1757486969] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_494번_1757486990] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_495번_1757487013] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_496번_1757487034] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_497번_1757487055] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_498번_1757487072] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_499번_1757487089] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_49번_1757478659] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_4번_1757478265] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_500번_1757487106] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_501번_1757487131] 저장 완료 (행수 3,000)
#   └─ 원본[인허가DB_502번_1757487148] 저장 완료 (행수 3,000)
# ...
#   └─ 원본[포털DB_12번_1757493789] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_13번_1757493796] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_14번_1757493802] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_15번_1757493808] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_16번_1757493813] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_17번_1757493820] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_18번_1757493823] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_19번_1757493826] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_1번_1757493707] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_20번_1757493829] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_21번_1757493850] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_22번_1757493853] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_23번_1757493856] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_24번_1757493860] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_25번_1757493863] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_26번_1757493867] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_27번_1757493871] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_28번_1757493874] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_29번_1757493879] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_2번_1757493709] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_30번_1757493882] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_31번_1757493900] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_32번_1757493903] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_33번_1757493907] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_34번_1757493911] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_35번_1757493915] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_36번_1757493919] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_37번_1757493923] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_38번_1757493927] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_39번_1757493931] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_3번_1757493728] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_40번_1757493935] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_41번_1757493950] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_42번_1757493954] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_43번_1757493959] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_44번_1757493962] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_45번_1757493967] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_46번_1757493970] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_47번_1757493974] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_48번_1757493979] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_49번_1757493983] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_4번_1757493732] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_50번_1757493986] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_51번_1757494004] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_52번_1757494008] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_53번_1757494012] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_54번_1757494016] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_55번_1757494020] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_56번_1757494024] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_57번_1757494028] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_58번_1757494032] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_59번_1757494036] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_5번_1757493736] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_60번_1757494040] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_61번_1757494056] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_62번_1757494060] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_63번_1757494064] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_64번_1757494068] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_65번_1757494072] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_66번_1757494075] 저장 완료 (행수 115)
#   └─ 원본[포털DB_6번_1757493740] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_7번_1757493744] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_8번_1757493748] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_9번_1757493753] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_10번_1757651479] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_11번_1757651501] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_12번_1757651504] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_13번_1757651507] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_14번_1757651510] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_15번_1757651513] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_16번_1757651516] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_17번_1757651519] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_18번_1757651522] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_19번_1757651525] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_1번_1757651456] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_20번_1757651528] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_21번_1757651546] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_22번_1757651549] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_23번_1757651552] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_24번_1757651555] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_25번_1757651558] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_26번_1757651560] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_27번_1757651563] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_28번_1757651566] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_29번_1757651569] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_2번_1757651458] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_30번_1757651572] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_31번_1757651587] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_32번_1757651590] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_33번_1757651593] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_34번_1757651596] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_35번_1757651599] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_36번_1757651602] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_37번_1757651606] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_38번_1757651609] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_39번_1757651612] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_3번_1757651460] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_40번_1757651615] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_41번_1757651626] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_42번_1757651630] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_43번_1757651634] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_44번_1757651638] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_45번_1757651642] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_46번_1757651646] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_47번_1757651650] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_48번_1757651654] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_49번_1757651658] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_4번_1757651462] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_50번_1757651662] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_51번_1757651676] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_52번_1757651680] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_53번_1757651684] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_54번_1757651688] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_55번_1757651692] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_56번_1757651696] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_57번_1757651700] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_58번_1757651704] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_59번_1757651708] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_5번_1757651465] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_60번_1757651712] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_61번_1757651725] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_62번_1757651729] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_63번_1757651733] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_64번_1757651737] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_65번_1757651741] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_66번_1757651745] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_67번_1757651749] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_68번_1757651753] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_69번_1757651757] 저장 완료 (행수 2,983)
#   └─ 원본[포털DB_6번_1757651467] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_7번_1757651470] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_8번_1757651473] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_9번_1757651476] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_10번_1757655397] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_11번_1757655415] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_12번_1757655421] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_13번_1757655427] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_14번_1757655433] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_15번_1757655439] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_16번_1757655445] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_17번_1757655452] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_18번_1757655459] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_19번_1757655462] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_1번_1757655357] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_20번_1757655465] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_21번_1757655479] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_22번_1757655482] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_23번_1757655485] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_24번_1757655488] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_25번_1757655491] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_26번_1757655494] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_27번_1757655497] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_28번_1757655500] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_29번_1757655502] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_2번_1757655361] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_30번_1757655505] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_31번_1757655513] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_32번_1757655516] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_33번_1757655519] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_34번_1757655522] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_35번_1757655524] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_36번_1757655529] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_37번_1757655532] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_38번_1757655535] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_39번_1757655538] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_3번_1757655365] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_40번_1757655541] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_41번_1757655555] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_42번_1757655558] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_43번_1757655561] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_44번_1757655564] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_45번_1757655567] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_46번_1757655570] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_47번_1757655574] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_48번_1757655577] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_49번_1757655579] 저장 완료 (행수 2,573)
#   └─ 원본[포털DB_4번_1757655369] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_5번_1757655374] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_6번_1757655378] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_7번_1757655383] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_8번_1757655387] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_9번_1757655392] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_10번_1757657266] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_11번_1757657276] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_12번_1757657279] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_13번_1757657281] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_14번_1757657284] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_15번_1757657286] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_16번_1757657289] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_17번_1757657292] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_18번_1757657295] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_19번_1757657298] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_1번_1757657242] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_20번_1757657301] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_21번_1757657324] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_22번_1757657327] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_23번_1757657330] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_24번_1757657333] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_25번_1757657336] 저장 완료 (행수 2,890)
#   └─ 원본[포털DB_2번_1757657245] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_3번_1757657248] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_4번_1757657251] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_5번_1757657254] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_6번_1757657256] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_7번_1757657259] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_8번_1757657261] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_9번_1757657264] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_10번_1757562325] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_11번_1757562342] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_12번_1757562345] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_13번_1757562349] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_14번_1757562353] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_15번_1757562356] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_16번_1757562359] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_17번_1757562363] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_18번_1757562367] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_19번_1757562371] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_1번_1757562298] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_20번_1757562375] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_21번_1757562399] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_22번_1757562403] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_23번_1757562407] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_24번_1757562411] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_25번_1757562415] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_26번_1757562419] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_27번_1757562423] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_28번_1757562427] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_29번_1757562431] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_2번_1757562301] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_30번_1757562435] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_31번_1757562456] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_32번_1757562460] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_33번_1757562464] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_34번_1757562468] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_35번_1757562472] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_36번_1757562476] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_37번_1757562480] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_38번_1757562484] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_39번_1757562488] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_3번_1757562303] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_40번_1757562492] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_41번_1757562513] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_42번_1757562517] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_43번_1757562521] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_44번_1757562525] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_45번_1757562529] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_46번_1757562533] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_47번_1757562537] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_48번_1757562541] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_49번_1757562545] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_4번_1757562307] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_50번_1757562549] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_51번_1757562572] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_52번_1757562576] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_53번_1757562580] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_54번_1757562584] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_55번_1757562588] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_56번_1757562592] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_57번_1757562596] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_58번_1757562600] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_59번_1757562604] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_5번_1757562310] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_60번_1757562608] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_61번_1757562623] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_62번_1757562627] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_63번_1757562631] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_64번_1757562635] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_65번_1757562639] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_66번_1757562643] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_67번_1757562647] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_68번_1757562651] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_69번_1757562655] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_6번_1757562313] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_70번_1757562659] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_71번_1757562677] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_72번_1757562681] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_73번_1757562685] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_74번_1757562690] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_75번_1757562694] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_76번_1757562698] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_77번_1757562702] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_78번_1757562706] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_79번_1757562710] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_7번_1757562316] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_80번_1757562713] 저장 완료 (행수 660)
#   └─ 원본[포털DB_8번_1757562319] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_9번_1757562322] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_10번_1757573329] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_11번_1757573348] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_12번_1757573351] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_13번_1757573355] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_14번_1757573358] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_15번_1757573361] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_16번_1757573364] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_17번_1757573368] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_18번_1757573372] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_19번_1757573375] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_1번_1757573302] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_20번_1757573378] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_21번_1757573400] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_22번_1757573403] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_23번_1757573406] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_24번_1757573409] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_25번_1757573413] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_26번_1757573416] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_27번_1757573419] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_28번_1757573423] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_29번_1757573425] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_2번_1757573304] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_30번_1757573428] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_31번_1757573448] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_32번_1757573451] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_33번_1757573454] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_34번_1757573457] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_35번_1757573461] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_36번_1757573464] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_37번_1757573467] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_38번_1757573471] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_39번_1757573475] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_3번_1757573307] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_40번_1757573479] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_41번_1757573499] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_42번_1757573503] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_43번_1757573506] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_44번_1757573510] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_45번_1757573514] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_46번_1757573517] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_47번_1757573520] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_48번_1757573524] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_49번_1757573528] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_4번_1757573310] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_50번_1757573532] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_51번_1757573550] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_52번_1757573554] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_53번_1757573558] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_54번_1757573562] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_55번_1757573566] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_56번_1757573570] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_57번_1757573574] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_58번_1757573578] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_59번_1757573582] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_5번_1757573313] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_60번_1757573586] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_61번_1757573601] 저장 완료 (행수 223)
#   └─ 원본[포털DB_6번_1757573316] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_7번_1757573319] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_8번_1757573323] 저장 완료 (행수 3,000)
#   └─ 원본[포털DB_9번_1757573326] 저장 완료 (행수 3,000)
#
# ✅ 전체 완료: DB별 통합 + 원본파일별(merchant_code 포함) CSV 생성

# %%
# -*- coding: utf-8 -*-
"""
기업DB 전용 병합 스크립트

기능 요약
- ./기업DB 폴더 아래의 모든 *.xlsx 파일을 읽어 하나로 병합
- 파일명에서 업종을 추출해 '업종' 컬럼으로 저장 (예: '음식점_2024-03.xlsx' → 업종='음식점')
- 메타 컬럼(source_db, src_file) 추가
- merchant_code 부여(접두사 C + 7자리 일련번호: C0000001 ...)
- 결과 저장:
    1) 기업DB_merged.utf8.csv / 기업DB_merged.csv (통합본, src_file 제외)
    2) 기업DB_by_file/<원본파일명>_with_code.* (원본 파일별, merchant_code 포함)

메모
- 결측치는 저장 직전에 공백("")으로 변환합니다.
"""

import re
import json
import pandas as pd
from pathlib import Path
from typing import Optional, List, Dict

# =====================================================
# 설정: 경로
#   - ROOT_DIR: 기업DB 엑셀들이 모여있는 폴더(상대 경로)
#   - OUT_DIR : 결과 CSV를 떨어뜨릴 폴더
# =====================================================
ROOT_DIR = Path("./기업DB")        # 기업DB 단일 폴더
OUT_DIR  = Path("./_merged_csv")   # 결과 폴더
OUT_DIR.mkdir(parents=True, exist_ok=True)

# =====================================================
# 설정: 코드 접두사
#   - 기업DB는 'C'를 접두사로 사용해 merchant_code 부여
# =====================================================
DB_NAME = "기업DB"
ID_PREFIX = {"기업DB": "C"}

# =====================================================
# 파일명 → 업종 추출
#   - 예) "음식점_2024-03.xlsx" → "음식점"
#   - '_' 가 없으면 전체 파일명(stem)을 그대로 사용
# =====================================================
def extract_file_category_from_name(path: Path) -> str:
    """원본 파일명에서 업종명을 추출해 반환."""
    stem = path.stem
    return stem.split("_", 1)[0].strip() if "_" in stem else stem.strip()

# =====================================================
# 입출력/정리 유틸
#   - 엑셀 로드 시 모든 값을 문자열로 읽고 strip
#   - 공백만 있는 문자열은 None으로 두되, 저장 직전에 공백으로 바꿈
# =====================================================
def read_excel_safe(path: Path) -> Optional[pd.DataFrame]:
    """엑셀 첫 시트를 문자열로 안전하게 읽어 DataFrame 반환."""
    try:
        df = pd.read_excel(path, sheet_name=0, engine="openpyxl", dtype=str)
        # 모든 문자열 trim. 공백만 있는 셀은 None으로 두고, 저장 직전 일괄 공백 처리 예정.
        df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
        return df
    except Exception as e:
        print(f"[WARN] {path} 읽기 실패: {e}")
        return None

def make_codes(prefix_letter: str, n: int, width: int = 7) -> List[str]:
    """
    merchant_code 생성 유틸.
    예) prefix='C', n=3 → ['C0000001','C0000002','C0000003']
    """
    return [f"{prefix_letter}{i:0{width}d}" for i in range(1, n+1)]

def sanitize_cp949_value(x):
    """
    CP949 저장 시 인코딩 불가 문자는 제거(errors='ignore')하도록 변환.
    None → "" 로 처리.
    """
    if x is None:
        return ""
    if not isinstance(x, str):
        x = str(x)
    return x.encode("cp949", errors="ignore").decode("cp949")

def sanitize_df_cp949(df: pd.DataFrame) -> pd.DataFrame:
    """DataFrame 전체를 CP949 안전 문자열로 변환한 사본 반환."""
    out = df.copy()
    for col in out.columns:
        out[col] = out[col].map(sanitize_cp949_value)
    return out

# =====================================================
# 정제 로직
#   - 파일명에서 추출한 업종을 '업종' 컬럼으로 세팅
#   - 이름(업체명) 결측도 제거하지 않음(요구사항)
# =====================================================
def clean_df(df: pd.DataFrame, file_category: str) -> pd.DataFrame:
    """
    단일 파일 단위 정제:
    - '업종' 컬럼을 파일명에서 추출한 값으로 채움(기존 값이 있더라도 덮어씀)
    """
    df = df.copy()
    df["업종"] = (file_category or "").strip()
    print(f"[CLEAN] 업종='{file_category}' 설정 (행수 {len(df):,})")
    return df

# =====================================================
# 저장 유틸 (CSV만)
#   - UTF-8(BOM) + CP949 두 가지 포맷으로 저장
#   - 저장 직전에 결측을 공백("")으로 변환
# =====================================================
def save_csv(df: pd.DataFrame, path_base: Path, with_cp949: bool = True):
    """CSV(utf8/cp949) 저장. 결측은 공백으로 변환."""
    df_to_save = df.copy().fillna("")          # 결측 → 공백
    path_u8 = path_base.with_suffix(".utf8.csv")
    path_cp = path_base.with_suffix(".csv")

    # UTF-8(BOM) 저장: 엑셀 호환성을 위해 BOM 사용
    df_to_save.to_csv(path_u8, index=False, encoding="utf-8-sig")

    # CP949 저장: 필요한 경우만
    if with_cp949:
        df_cp949 = sanitize_df_cp949(df_to_save)
        df_cp949.to_csv(path_cp, index=False, encoding="cp949")

    return path_u8.name, (path_cp.name if with_cp949 else None)

# =====================================================
# 병합 + 정제 + 코드부여 + 저장(통합 + 원본파일별)
#   - ./기업DB/*.xlsx 를 모두 읽어 수직 병합
#   - 메타 컬럼(source_db, src_file) 추가
#   - merchant_code 부여 후
#     1) 기업DB_merged.* 로 통합 저장 (src_file 제외)
#     2) 기업DB_by_file/ 에 원본 파일별 저장 (merchant_code 포함)
# =====================================================
def merge_clean_and_save(db_name: str, files: List[Path], out_dir: Path):
    frames = []
    # 재현성을 위해 파일명 기준 정렬(merchant_code 부여 순서가 고정됨)
    for fp in sorted(files, key=lambda p: p.name):
        df = read_excel_safe(fp)
        if df is None:
            continue

        # 파일명에서 업종 추출
        file_cat = extract_file_category_from_name(fp)

        # 메타 컬럼 삽입 (원본을 수정하는 것이 아니라 DataFrame에만 추가)
        df.insert(0, "source_db", db_name)  # 스키마/라인리지용
        df.insert(1, "src_file", str(fp))   # 원본 파일 추적(파일별 저장에 사용)

        # 파일단위 정제(업종 세팅). 이름 결측도 제거하지 않음
        df = clean_df(df, file_cat)
        frames.append(df)

        print(f"  └─ 파일: {fp.name} → 업종: '{file_cat}', 행수 {len(df):,}")

    if not frames:
        print(f".[INFO] {db_name}: 병합할 파일 없음")
        return

    # 수직 병합 (열 집합이 달라도 union 형태로 맞춰 들어감)
    merged = pd.concat(frames, axis=0, ignore_index=True, sort=False)

    # 전부 결측인 완전 빈 행만 제거 (업체명 결측 등은 유지)
    merged.dropna(how="all", inplace=True)

    # merchant_code 부여(전체 길이 기준 일련번호)
    prefix_letter = ID_PREFIX.get(db_name, db_name[:1].upper())
    codes = make_codes(prefix_letter, len(merged), width=7)
    if "merchant_code" in merged.columns:
        merged = merged.drop(columns=["merchant_code"])
    # src_file 다음 컬럼 위치에 삽입 (메타→코드 순서를 깔끔히)
    merged.insert(2, "merchant_code", codes)

    # ---- [1] DB 통합 저장 (merchant_code 포함, src_file 제외) ----
    out_dir.mkdir(parents=True, exist_ok=True)
    base = out_dir / f"{db_name}_merged"
    merged_for_save = merged.drop(columns=["src_file"], errors="ignore")
    u8, cp = save_csv(merged_for_save, base, with_cp949=True)
    print(f"[OK] {db_name} 통합 저장 → {u8}, {cp} (행수 {len(merged_for_save):,})")

    # ---- [2] 원본 파일별 저장 (merchant_code 포함) ----
    by_file_dir = out_dir / f"{db_name}_by_file"
    by_file_dir.mkdir(parents=True, exist_ok=True)

    # src_file 기준으로 그룹핑해서 파일별 결과 저장
    for src, sub in merged.groupby("src_file", dropna=False):
        src_path = Path(src)
        stem = src_path.stem
        sub_to_save = sub.drop(columns=["src_file"], errors="ignore")
        save_csv(sub_to_save, by_file_dir / f"{stem}_with_code", with_cp949=True)
        print(f"  └─ 원본[{stem}] + merchant_code 저장 완료 (행수 {len(sub_to_save):,})")

# =====================================================
# 메인
#   - ./기업DB/*.xlsx 파일들을 모두 병합 처리
# =====================================================
def main():
    files = list(ROOT_DIR.glob("*.xlsx"))
    if not files:
        print(f"[INFO] 엑셀 없음: {ROOT_DIR}")
        return
    merge_clean_and_save(DB_NAME, files, OUT_DIR)
    print("\n✅ 완료: 기업DB → 통합본 + 원본파일별(with merchant_code) CSV 생성")

if __name__ == "__main__":
    main()
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='가구 내 고용활동 및 달리 분류되지 않은 자가 소비 생산활동' 설정 (행수 1)
#   └─ 파일: 가구 내 고용활동 및 달리 분류되지 않은 자가 소비 생산활동_기업DB_1번_1758167036.xlsx → 업종: '가구 내 고용활동 및 달리 분류되지 않은 자가 소비 생산활동', 행수 1
# [CLEAN] 업종='건설업' 설정 (행수 360)
#   └─ 파일: 건설업_기업DB_2번_1758166362 (1).xlsx → 업종: '건설업', 행수 360
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='건설업' 설정 (행수 3,000)
#   └─ 파일: 건설업_기업DB_2번_1758166362 (2).xlsx → 업종: '건설업', 행수 3,000
# [CLEAN] 업종='광업' 설정 (행수 148)
#   └─ 파일: 광업_기업DB_1번_1758166862.xlsx → 업종: '광업', 행수 148
# [CLEAN] 업종='교육 서비스업' 설정 (행수 176)
#   └─ 파일: 교육 서비스업_기업DB_1번_1758166694.xlsx → 업종: '교육 서비스업', 행수 176
# [CLEAN] 업종='국제 및 외국기관' 설정 (행수 46)
#   └─ 파일: 국제 및 외국기관_기업DB_1번_1758166996.xlsx → 업종: '국제 및 외국기관', 행수 46
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='금융 및 보험업' 설정 (행수 3,000)
#   └─ 파일: 금융 및 보험업_기업DB_1번_1758166617 (1).xlsx → 업종: '금융 및 보험업', 행수 3,000
# [CLEAN] 업종='금융 및 보험업' 설정 (행수 1,208)
#   └─ 파일: 금융 및 보험업_기업DB_1번_1758166617 (2).xlsx → 업종: '금융 및 보험업', 행수 1,208
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='금융 및 보험업' 설정 (행수 3,000)
#   └─ 파일: 금융 및 보험업_기업DB_1번_1758166617 (3).xlsx → 업종: '금융 및 보험업', 행수 3,000
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='도매 및 소매업' 설정 (행수 3,000)
#   └─ 파일: 도매 및 소매업_기업DB_1번_1758166301 (1).xlsx → 업종: '도매 및 소매업', 행수 3,000
# [CLEAN] 업종='도매 및 소매업' 설정 (행수 304)
#   └─ 파일: 도매 및 소매업_기업DB_1번_1758166301 (2).xlsx → 업종: '도매 및 소매업', 행수 304
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='도매 및 소매업' 설정 (행수 3,000)
#   └─ 파일: 도매 및 소매업_기업DB_1번_1758166301 (3).xlsx → 업종: '도매 및 소매업', 행수 3,000
# [CLEAN] 업종='보건업 및 사회복지 서비스업' 설정 (행수 45)
#   └─ 파일: 보건업 및 사회복지 서비스업_기업DB_1번_1758166744.xlsx → 업종: '보건업 및 사회복지 서비스업', 행수 45
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='부동산업' 설정 (행수 3,000)
#   └─ 파일: 부동산업_기업DB_2번_1758166440 (1).xlsx → 업종: '부동산업', 행수 3,000
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='부동산업' 설정 (행수 3,000)
#   └─ 파일: 부동산업_기업DB_2번_1758166440 (2).xlsx → 업종: '부동산업', 행수 3,000
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='부동산업' 설정 (행수 2,739)
#   └─ 파일: 부동산업_기업DB_3번_1758166444.xlsx → 업종: '부동산업', 행수 2,739
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='숙박 및 음식점업' 설정 (행수 786)
#   └─ 파일: 숙박 및 음식점업_기업DB_1번_1758166580.xlsx → 업종: '숙박 및 음식점업', 행수 786
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='운수 및 창고업' 설정 (행수 1,811)
#   └─ 파일: 운수 및 창고업_기업DB_1번_1758166476.xlsx → 업종: '운수 및 창고업', 행수 1,811
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='정보통신업' 설정 (행수 2,981)
#   └─ 파일: 정보통신업_기업DB_1번_1758166406.xlsx → 업종: '정보통신업', 행수 2,981
# [CLEAN] 업종='제조업' 설정 (행수 236)
#   └─ 파일: 제조업_기업DB_6번_1758166111 (1).xlsx → 업종: '제조업', 행수 236
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='제조업' 설정 (행수 3,000)
#   └─ 파일: 제조업_기업DB_6번_1758166111 (2).xlsx → 업종: '제조업', 행수 3,000
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='제조업' 설정 (행수 3,000)
#   └─ 파일: 제조업_기업DB_6번_1758166111 (3).xlsx → 업종: '제조업', 행수 3,000
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='제조업' 설정 (행수 3,000)
#   └─ 파일: 제조업_기업DB_6번_1758166111 (4).xlsx → 업종: '제조업', 행수 3,000
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='제조업' 설정 (행수 3,000)
#   └─ 파일: 제조업_기업DB_6번_1758166111 (5).xlsx → 업종: '제조업', 행수 3,000
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_28076\1562483089.py:60: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: (x if not isinstance(x, str) else (x.strip() if x.strip() != "" else None)))
# [CLEAN] 업종='제조업' 설정 (행수 3,000)
#   └─ 파일: 제조업_기업DB_6번_1758166111 (6).xlsx → 업종: '제조업', 행수 3,000
# [OK] 기업DB 통합 저장 → 기업DB_merged.utf8.csv, 기업DB_merged.csv (행수 46,841)
#   └─ 원본[가구 내 고용활동 및 달리 분류되지 않은 자가 소비 생산활동_기업DB_1번_1758167036] + merchant_code 저장 완료 (행수 1)
#   └─ 원본[건설업_기업DB_2번_1758166362 (1)] + merchant_code 저장 완료 (행수 360)
#   └─ 원본[건설업_기업DB_2번_1758166362 (2)] + merchant_code 저장 완료 (행수 3,000)
#   └─ 원본[광업_기업DB_1번_1758166862] + merchant_code 저장 완료 (행수 148)
#   └─ 원본[교육 서비스업_기업DB_1번_1758166694] + merchant_code 저장 완료 (행수 176)
#   └─ 원본[국제 및 외국기관_기업DB_1번_1758166996] + merchant_code 저장 완료 (행수 46)
#   └─ 원본[금융 및 보험업_기업DB_1번_1758166617 (1)] + merchant_code 저장 완료 (행수 3,000)
#   └─ 원본[금융 및 보험업_기업DB_1번_1758166617 (2)] + merchant_code 저장 완료 (행수 1,208)
#   └─ 원본[금융 및 보험업_기업DB_1번_1758166617 (3)] + merchant_code 저장 완료 (행수 3,000)
#   └─ 원본[도매 및 소매업_기업DB_1번_1758166301 (1)] + merchant_code 저장 완료 (행수 3,000)
#   └─ 원본[도매 및 소매업_기업DB_1번_1758166301 (2)] + merchant_code 저장 완료 (행수 304)
#   └─ 원본[도매 및 소매업_기업DB_1번_1758166301 (3)] + merchant_code 저장 완료 (행수 3,000)
#   └─ 원본[보건업 및 사회복지 서비스업_기업DB_1번_1758166744] + merchant_code 저장 완료 (행수 45)
#   └─ 원본[부동산업_기업DB_2번_1758166440 (1)] + merchant_code 저장 완료 (행수 3,000)
#   └─ 원본[부동산업_기업DB_2번_1758166440 (2)] + merchant_code 저장 완료 (행수 3,000)
#   └─ 원본[부동산업_기업DB_3번_1758166444] + merchant_code 저장 완료 (행수 2,739)
#   └─ 원본[숙박 및 음식점업_기업DB_1번_1758166580] + merchant_code 저장 완료 (행수 786)
#   └─ 원본[운수 및 창고업_기업DB_1번_1758166476] + merchant_code 저장 완료 (행수 1,811)
#   └─ 원본[정보통신업_기업DB_1번_1758166406] + merchant_code 저장 완료 (행수 2,981)
#   └─ 원본[제조업_기업DB_6번_1758166111 (1)] + merchant_code 저장 완료 (행수 236)
#   └─ 원본[제조업_기업DB_6번_1758166111 (2)] + merchant_code 저장 완료 (행수 3,000)
#   └─ 원본[제조업_기업DB_6번_1758166111 (3)] + merchant_code 저장 완료 (행수 3,000)
#   └─ 원본[제조업_기업DB_6번_1758166111 (4)] + merchant_code 저장 완료 (행수 3,000)
#   └─ 원본[제조업_기업DB_6번_1758166111 (5)] + merchant_code 저장 완료 (행수 3,000)
#   └─ 원본[제조업_기업DB_6번_1758166111 (6)] + merchant_code 저장 완료 (행수 3,000)
#
# ✅ 완료: 기업DB → 통합본 + 원본파일별(with merchant_code) CSV 생성
